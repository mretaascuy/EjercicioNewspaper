# %% [markdown]
# # Solucion ejercicio Newspaper

# %%
# %load_ext autoreload #directivas a jupyter 
# %autoreload 2 #directiva autoreload con parametro 2

# %%
import ej1
x=ej1.body('https://www.nytimes.com/2016/08/07/education/edlife/kenneth-goldsmith-on-wasting-time-on-the-internet.html')

for key,value in x.items():
    print("La cantidad de veces que aparece la palabra {} es {}".format(key,value))
# Out:
# La cantidad de veces que aparece la palabra Two es 1
# La cantidad de veces que aparece la palabra years es 1
# La cantidad de veces que aparece la palabra ago es 1
# La cantidad de veces que aparece la palabra Kenneth es 1
# La cantidad de veces que aparece la palabra Goldsmith es 3
# La cantidad de veces que aparece la palabra the es 17
# La cantidad de veces que aparece la palabra University es 1
# La cantidad de veces que aparece la palabra of es 8
# La cantidad de veces que aparece la palabra Pennsylvania es 1
# La cantidad de veces que aparece la palabra poet es 2
# La cantidad de veces que aparece la palabra and es 7
# La cantidad de veces que aparece la palabra conceptual es 1
# La cantidad de veces que aparece la palabra artist es 1
# La cantidad de veces que aparece la palabra taught es 1
# La cantidad de veces que aparece la palabra a es 6
# La cantidad de veces que aparece la palabra creative es 4
# La cantidad de veces que aparece la palabra writing es 1
# ...
